# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# # Part 1 - Data Preprocessing

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('/content/diabetes.csv')
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = dataset.iloc[:, 0:8]
y = dataset.iloc[:, 8]
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Part 2 - Now let's make the ANN!

# %%
# Importing the Keras libraries and packages
# keras makes the calculation part very easy and efficient
#tensorflow is also used for the same

import keras

from keras.models import Sequential
from keras.layers import Dense

#Dense is used to create hidden layer
#sequential is used to create a model(dancha)for ann

# %%
# Initialising the ANN
classifier = Sequential()

#creating an object. Now ANN implemented with a name classifier

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(8,activation='relu',input_dim=8))

#Using the dense library make the first hidden layer , give the number of neurons , name of the activation funct. to use , and the give the input dimention (size of the input).

# %%
# Adding the second hidden layer
classifier.add(Dense( 8,activation='relu'))

# %%
# Adding the output layer
classifier.add(Dense(1,  activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model_history = classifier.fit(X_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 1s 3ms/step - loss: 5.5164 - accuracy: 0.6254
# Epoch 2/100
# 62/62 [==============================] - 0s 3ms/step - loss: 1.6719 - accuracy: 0.4593
# Epoch 3/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.9293 - accuracy: 0.3730
# Epoch 4/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7797 - accuracy: 0.3632
# Epoch 5/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7476 - accuracy: 0.5456
# Epoch 6/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7260 - accuracy: 0.6596
# Epoch 7/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7134 - accuracy: 0.6580
# Epoch 8/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6916 - accuracy: 0.6694
# Epoch 9/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.6580
# Epoch 10/100
# ...

# %% [markdown]
# # Part 3 - Making the predictions and evaluating the model

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
y_pred
# Out:
# 5/5 [==============================] - 0s 3ms/step
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[105,   2],
#        [ 42,   5]])

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.7142857142857143
